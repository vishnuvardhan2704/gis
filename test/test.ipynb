# %%
# !pip install earthengine-api
import ee
ee.Authenticate()
ee.Initialize(project='gisproj-487215')
# Out:
# ...
#
# [notice] A new release of pip is available: 26.0 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
import ee
ee.Initialize()

aoi = ee.Geometry.Point([78.4867, 17.3850]).buffer(100000)

clay = ee.Image("OpenLandMap/SOL/SOL_CLAY-PSD_USDA-3A1A1A_M/v02") \
        .select("b0") \
        .clip(aoi)

print(clay.bandNames().getInfo())
# Out:
# ---------------------------------------------------------------------------
# HttpError                                 Traceback (most recent call last)
# File ~/gisproj/venv/lib/python3.12/site-packages/ee/data.py:349, in _execute_cloud_call(call, num_retries)
#     348 try:
# --> 349   return call.execute(num_retries=num_retries)
#     350 except googleapiclient.errors.HttpError as e:
#
# File ~/gisproj/venv/lib/python3.12/site-packages/googleapiclient/_helpers.py:130, in positional.<locals>.positional_decorator.<locals>.positional_wrapper(*args, **kwargs)
#     129         logger.warning(message)
# --> 130 return wrapped(*args, **kwargs)
#
# File ~/gisproj/venv/lib/python3.12/site-packages/googleapiclient/http.py:938, in HttpRequest.execute(self, http, num_retries)
#     937 if resp.status >= 300:
# --> 938     raise HttpError(resp, content, uri=self.uri)
#     939 return self.postproc(resp, content)
#
# ...

# %%
sand = ee.Image("OpenLandMap/SOL/SOL_SAND-WFRACTION_USDA-3A1A1A_M/v02") \
          .select("b0") \
          .clip(test_point.buffer(10000))

print("Sand band names:", sand.bandNames().getInfo())
# Out:
# ---------------------------------------------------------------------------
# HttpError                                 Traceback (most recent call last)
# File ~/gisproj/venv/lib/python3.12/site-packages/ee/data.py:349, in _execute_cloud_call(call, num_retries)
#     348 try:
# --> 349   return call.execute(num_retries=num_retries)
#     350 except googleapiclient.errors.HttpError as e:
#
# File ~/gisproj/venv/lib/python3.12/site-packages/googleapiclient/_helpers.py:130, in positional.<locals>.positional_decorator.<locals>.positional_wrapper(*args, **kwargs)
#     129         logger.warning(message)
# --> 130 return wrapped(*args, **kwargs)
#
# File ~/gisproj/venv/lib/python3.12/site-packages/googleapiclient/http.py:938, in HttpRequest.execute(self, http, num_retries)
#     937 if resp.status >= 300:
# --> 938     raise HttpError(resp, content, uri=self.uri)
#     939 return self.postproc(resp, content)
#
# ...

# %%
clay = ee.Image("OpenLandMap/SOL/SOL_CLAY-WFRACTION_USDA-3A1A1A_M/v02") \
        .select("b0") \
        .clip(aoi)
print(clay)
# Out:
# ee.Image({
#   "functionInvocationValue": {
#     "functionName": "Image.clip",
#     "arguments": {
#       "geometry": {
#         "functionInvocationValue": {
#           "functionName": "Geometry.buffer",
#           "arguments": {
#             "distance": {
#               "constantValue": 100000
#             },
#             "geometry": {
#               "functionInvocationValue": {
#                 "functionName": "GeometryConstructors.Point",
#                 "arguments": {
#                   "coordinates": {
#                     "constantValue": [
#                       78.4867,
#                       17.385
#                     ]
#                   }
#                 }
#               }
#             }
#           }
#         }
#       },
#       "input": {
#         "functionInvocationValue": {
#           "functionName": "Image.select",
#           "arguments": {
#             "bandSelectors": {
#               "constantValue": [
#                 "b0"
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# HttpError                                 Traceback (most recent call last)
# File ~/gisproj/venv/lib/python3.12/site-packages/ee/data.py:349, in _execute_cloud_call(call, num_retries)
#     348 try:
# --> 349   return call.execute(num_retries=num_retries)
#     350 except googleapiclient.errors.HttpError as e:
#
# File ~/gisproj/venv/lib/python3.12/site-packages/googleapiclient/_helpers.py:130, in positional.<locals>.positional_decorator.<locals>.positional_wrapper(*args, **kwargs)
#     129         logger.warning(message)
# --> 130 return wrapped(*args, **kwargs)
#
# File ~/gisproj/venv/lib/python3.12/site-packages/googleapiclient/http.py:938, in HttpRequest.execute(self, http, num_retries)
#     937 if resp.status >= 300:
# --> 938     raise HttpError(resp, content, uri=self.uri)
#     939 return self.postproc(resp, content)
#
# ...
